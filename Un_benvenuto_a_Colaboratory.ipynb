# %% [markdown]
# <a href="https://colab.research.google.com/github/carradoremarco/COVID-19/blob/master/Un_benvenuto_a_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Ti diamo il benvenuto in Colab</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>&#40;Novità&#41; Prova l'API Gemini</h2>
#   <ul>
#   <li><a href="https://makersuite.google.com/app/apikey">Generate a Gemini API key</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/google/generative-ai-docs/blob/main/site/en/tutorials/python_quickstart.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API: Quickstart with Python</a></li>
#   <li><a href="https://colab.research.google.com/notebooks/snippets/gemini.ipynb?utm_medium=link&utm_campaign=gemini">Gemini API code sample</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# Se conosci già Colab, guarda questo video per avere informazioni sulle tabelle interattive, sulla visualizzazione della cronologia del codice eseguito e sulla tavolozza dei comandi.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Miniatura di un video che mostra 3 funzionalità fantastiche di Google Colab' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>Cos'è Colab?</h2>
# </div>
#
# Colab, o "Colaboratory", ti permette di scrivere ed eseguire Python nel tuo browser con
# - Nessuna configurazione necessaria
# - Accesso alle GPU senza costi
# - Condivisione semplificata
#
# Che tu sia <strong>studente</strong>, <strong>data scientist</strong> o <strong>ricercatore AI</strong>, Colab può semplificarti il lavoro. Guarda <a href="https://www.youtube.com/watch?v=inN8seMm7UI">questo video introduttivo su Colab</a> per ulteriori informazioni oppure inizia qui sotto.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Introduzione</strong>
# </div>
#
# Il documento che stai leggendo non è una pagina web statica, ma un ambiente interattivo chiamato <strong>blocco note Colab</strong> che ti permette di scrivere ed eseguire codice.
#
# Ad esempio, qui vediamo una <strong>cella di codice</strong> con un breve script Python che calcola un valore, lo archivia in una variabile e stampa i risultati:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# Per eseguire il codice nella cella sopra, selezionala con un clic e poi premi il pulsante Riproduci a sinistra del codice o usa la scorciatoia da tastiera "Comando/Ctrl+Invio". Per modificare il codice, fai clic sulla cella e inizia a modificare.
#
# Le variabili che definisci in una cella possono essere usate in seguito in altre celle:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# I blocchi note Colab ti permettono di combinare <strong>codice eseguibile</strong> e <strong>RTF</strong> in un unico documento, insieme a <strong>immagini</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> e altro ancora. Quando crei dei blocchi note Colab, questi vengono archiviati nel tuo account Google Drive. Puoi condividere facilmente i blocchi note Colab con collaboratori o amici e dare loro la possibilità di commentare o modificare. Leggi ulteriori informazioni in <a href="/notebooks/basic_features_overview.ipynb">Panoramica di Colab</a>. Per creare un nuovo blocco note Colab, puoi usare il menu File qui sopra o questo link: <a href="http://colab.research.google.com#create=true">crea un nuovo blocco note Colab</a>.
#
# I blocchi note Colab sono blocchi note Jupyter ospitati da Colab. Per ulteriori informazioni sul progetto Jupyter, visita <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# Con Colab puoi sfruttare tutta la potenza delle librerie Python per analizzare e visualizzare i dati. La seguente cella di codice usa <strong>numpy</strong> per generare alcuni dati casuali e usa <strong>matplotlib</strong> per visualizzarli. Per modificare il codice, fai clic sulla cella e inizia a modificare.

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %% [markdown]
# Puoi importare i tuoi dati nei blocchi note Colab dal tuo account Google Drive, inclusi i fogli di lavoro, da GitHub e molte altre fonti. Per ulteriori informazioni sull'importazione dei dati e sulle possibilità di utilizzo di Colab per la data science, vedi i link di seguito, sotto <a href="#working-with-data">Utilizzo dei dati</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# Con Colab puoi importare un set di dati immagine, addestrare un classificatore di immagini e valutare il modello, il tutto in <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">poche righe di codice</a>. I blocchi note Colab eseguono il codice sui server cloud di Google, il che significa che puoi utilizzare la potenza dell'hardware Google, tra cui <a href="#using-accelerated-hardware">GPU e TPU</a>, a prescindere dalla potenza della tua macchina. Ti serve solo un browser.

# %% [markdown]
# Colab è ampiamente utilizzato dalla community del machine learning con applicazioni che includono:
# - Introduzione a TensorFlow
# - Sviluppo e addestramento di reti neurali
# - Esperimenti con TPU
# - Diffusione della ricerca sull'AI
# - Creazione di tutorial
#
# Per vedere degli esempi di blocchi note Colab che dimostrano le applicazioni di machine learning, vedi i seguenti <a href="#machine-learning-examples">esempi di machine learning</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Altre risorse
#
# ### Utilizzo dei blocchi note in Colab
#
# </div>
#
# - [Panoramica di Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guida a Markdown](/notebooks/markdown_guide.ipynb)
# - [Importazione di librerie e installazione di dipendenze](/notebooks/snippets/importing_libraries.ipynb)
# - [Salvataggio e caricamento dei blocchi note in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Moduli interattivi](/notebooks/forms.ipynb)
# - [Widget interattivi](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Utilizzo dei dati
# </div>
#
# - [Caricamento dei dati: Drive, Fogli e Google Cloud Storage](/notebooks/io.ipynb)
# - [Grafici: visualizzare i dati](/notebooks/charts.ipynb)
# - [Introduzione a BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine Learning Crash Course
#
# <div>
#
# Ecco alcuni dei blocchi note dal corso online sul machine learning di Google. Vedi il <a href="https://developers.google.com/machine-learning/crash-course/">sito web del corso completo</a> per ulteriori informazioni.
# - [Introduzione al DataFrame Pandas](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Regressione lineare con tf.keras usando dati sintetici](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Utilizzo di hardware accelerato
# </div>
#
# - [TensorFlow con GPU](/notebooks/gpu.ipynb)
# - [TensorFlow con TPU](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Esempi in primo piano
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">Scambio di voce NeMo</a>. Usa il toolkit di AI di conversazione NeMo di Nvidia per scambiare una voce in un frammento audio con una voce generata automaticamente.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Riaddestramento di un classificatore di immagini</a>: crea un modello Keras utilizzando un classificatore di immagini preaddestrato per distinguere i fiori.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Classificazione del testo</a>: classifica le recensioni dei film IMDB come <em>positive</em> o <em>negative</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Trasferimento dello stile</a>: usa il deep learning per trasferire lo stile da un'immagine all'altra.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: usa un modello di machine learning per rispondere alle domande del set di dati SQuAD.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Interpolazione video</a>: prevedi gli eventi di un video tra il primo e l'ultimo frame.

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-15rq51p5
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-15rq51p5
#   Resolved https://github.com/openai/whisper.git to commit ba3f3cd54b0e5b8ce1ab3de13e32122d0d5f98ab
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (0.58.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (1.25.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.2.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (4.66.2)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (10.1.0)
# Collecting tiktoken (from openai-whisper==20231117)
#   Downloading tiktoken-0.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: triton<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from openai-whisper==20231117) (2.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from triton<3,>=2.0.0->openai-whisper==20231117) (3.13.3)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba->openai-whisper==20231117) (0.41.1)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2023.12.25)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken->openai-whisper==20231117) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (4.10.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->openai-whisper==20231117) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->openai-whisper==20231117)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->openai-whisper==20231117)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->openai-whisper==20231117)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->openai-whisper==20231117)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper==20231117)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken->openai-whisper==20231117) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->openai-whisper==20231117) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->openai-whisper==20231117) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20231117-py3-none-any.whl size=802826 sha256=e6f801f5b8acbec871241b8e65f3ae6b4214eac847971fe959fcdf81efa1fe75
#   Stored in directory: /tmp/pip-ephem-wheel-cache-yxtlu_it/wheels/8b/6c/d0/622666868c179f156cf595c8b6f06f88bc5d80c4b31dccaa03
# Successfully built openai-whisper
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, tiktoken, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, openai-whisper
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 openai-whisper-20231117 tiktoken-0.6.0

# %%
import whisper

# %%
model = whisper.load_model('base')

# %%
#@markdown <br><center><img src='https://raw.githubusercontent.com/sudo-ken/FFmpeg-for-GDrive/master/res/ffmpeg.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Upgrade FFmpeg to v4.2.2</h3></center><br>
from IPython.display import clear_output
import os, urllib.request
HOME = os.path.expanduser("~")
pathDoneCMD = f'{HOME}/doneCMD.sh'
if not os.path.exists(f"{HOME}/.ipython/ttmg.py"):
    hCode = "https://raw.githubusercontent.com/sudo-ken/FFmpeg-for-GDrive/master/ttmg.py"
    urllib.request.urlretrieve(hCode, f"{HOME}/.ipython/ttmg.py")

from ttmg import (
    loadingAn,
    textAn,
)

loadingAn(name="lds")
textAn("Installing Dependencies...", ty='twg')
os.system('pip install git+git://github.com/AWConant/jikanpy.git')
os.system('add-apt-repository -y ppa:jonathonf/ffmpeg-4')
os.system('apt-get update')
os.system('apt install mediainfo')
os.system('apt-get install ffmpeg')
clear_output()
print('Installation finished.')
# Out:
# Installation finished.

# %%
import os, sys, re

video_file_path = "/content/GMT20240316-153653_Recording.m4a" #@param {type:"string"}
output_file_extension = 'm4a' #@param ["m4a", "mp3", "opus", "flac", "wav"]

delsplit = re.search("\/(?:.(?!\/))+$", video_file_path)
output_file_path = re.search("^[\/].+\/", video_file_path)
filename = re.sub("^[\/]", "", delsplit.group(0))
filename_raw = re.sub(".{4}$", "", filename)

os.environ['inputFile'] = video_file_path
os.environ['outputPath'] = output_file_path.group(0)
os.environ['fileName'] = filename_raw
os.environ['fileType'] = output_file_extension

# !ffmpeg -hide_banner -i "$inputFile" -vn -c:a copy "$outputPath"/"$fileName"-audio."$fileType"

# %%
import os, sys, re

audio_file_path = "GMT20240316-153653_Recording.m4a" #@param {type:"string"}
output_file_type = "mp3" #@param ["mp3", "ogg", "m4a", "opus", "flac", "alac", "wav"]

output_file_path = re.search("^[\/].+\/", audio_file_path)
output_file_path_raw = output_file_path.group(0)
delsplit = re.search("\/(?:.(?!\/))+$", audio_file_path)
filename = re.sub("^[\/]", "", delsplit.group(0))
filename_raw = re.sub(".{4}$", "", filename)
file_extension = re.search(".{3}$", filename)
file_extension_raw = file_extension.group(0)

os.environ['inputFile'] = audio_file_path
os.environ['outputPath'] = output_file_path_raw
os.environ['fileExtension'] = output_file_type
os.environ['fileName'] = filename_raw

# !ffmpeg -hide_banner -i "$inputFile" "$outputPath"/"$fileName"converted."$fileExtension"
# Out:
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/content/GMT20240316-153653_Recording.m4a':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     creation_time   : 2024-03-16T15:36:53.000000Z
#   Duration: 00:46:05.31, start: 0.000000, bitrate: 127 kb/s
#   Stream #0:0(und): Audio: aac (LC) (mp4a / 0x6134706D), 32000 Hz, mono, fltp, 126 kb/s (default)
#     Metadata:
#       creation_time   : 2024-03-16T15:36:53.000000Z
#       handler_name    : AAC audio
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (aac (native) -> mp3 (libmp3lame))
# Press [q] to stop, [?] for help
# Output #0, mp3, to '/content//GMT20240316-153653_Recordingconverted.mp3':
#   Metadata:
#     major_brand     : mp42
#     minor_version   : 0
#     compatible_brands: isommp42
#     TSSE            : Lavf58.76.100
#   Stream #0:0(und): Audio: mp3, 32000 Hz, mono, fltp (default)
#     Metadata:
#       creation_time   : 2024-03-16T15:36:53.000000Z
#       handler_name    : AAC audio
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libmp3lame
# size=   16204kB time=00:46:05.30 bitrate=  48.0kbits/s speed=  86x
# video:0kB audio:16203kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.001917%

# %%
# load audio and pad/trim it to fit 30 seconds
audio = whisper.load_audio("GMT20240316-153653_Recordingconverted.wav")
audio = whisper.pad_or_trim(audio)

# %%
# make log-Mel spectrogram and move to the same device as the model
mel = whisper.log_mel_spectrogram(audio).to(model.device)

# %%
# detect the spoken language
_, probs = model.detect_language(mel)
print(f"Detected language: {max(probs, key=probs.get) }")
# Out:
# Detected language: it

# %%
# decode the audio
options = whisper.DecodingOptions()
result = whisper.decode(model, mel, options)

# %%
print(result.text)
# Out:
# per me vedere i dati. Le posso chiedere anche la sua età comune di residenza, nome della provincia di residenza. Allora ho 49 anni, residuo bucci nascco in provincia di Milano. Io ho due genitori di 82 e 83 anni.

# %%
with open("GMT20240316-153653_Recordingconverted.txt") as file:
  text = file.read()
  print(text)
# Out:
# per me vedere i dati. Le posso chiedere anche la sua età Comune di Residenza,
# nome della provincia di Residenza.
# Allora, ho 49 anni,
# resiega Bucinasco,
# in provincia di Milano,
# e ho due genitori di 82 e 83 anni.
# 82 sarebbe il papà.
# 82 la mamma, aluglio,
# e papà, settembre,
# ho 49, 84.
# OK,
# 82 e 84, il papà.
# E sono entrambi genitoriche,
# lei assiste,
# secco,
# assiste, sembaglio,
# mi raccontava, si.
# Posso chiedere il nome,
# allora delle persone che assiste,
# nome del papà e della mamma.
# Disco e mamma alfonsa.
# Scusi, non ho capito il papà.
# Prisco, come settere di Roma.
# OK, e la mamma.
# Alfonsa.
# Alfonsa.
# OK,
# potrei condividere anche adesso,
# magari la condivido, la tabella,
# che sto compilando,
# lei non prenda paura per la tabella,
# sono molto domani,
# ma inserirletti.
# I genitori,
# quindi risidono sempre a Bucinasco.
# Sì.
# È sempre in provincia di Milano.
# Sì.
# E lei,
# sui genitori sono,
# partenno conviventi con, non,
# non è partenno convivente con lei,
# è parente non convivente con lei,
# perché dobbiamo essere.
# Non convivente.
# Sì, sì, sì.
# Ecco di qui.
# Allora, condivido anche la schermata,
# non prenda paura.
# Ecco la qui in sostanza,
# questa qui, però, non prenda paura.
# Così, in modo anche di vederla,
# a nascici,
# perché la prima volta che la stiamo utilizzando, OK?
# Non si preò.
# Quindi questi sono i dati che ho già un po' compilato
# e procede allora.
# Se mi può indicare i nomi,
# già noi sappiamo nella vita di tutti i giorni,
# dobbiamo affrontare dei bisogni, OK?
# Dobbiamo risolvere dei problemi.
# E molto spesso è importante,
# quindi fare affidamento su le altre persone,
# sulle aiuto delle altre persone.
# Quando abbiamo dei bisogni,
# uno di qui possiamo aiutare le altre persone.
# Allora, le chiederai a questo punto di concentrarsi
# nella vita in generale,
# non ne lo specifico nel lavoro di assistenza.
# Le chiederai quindi di assistenza
# dei suoi genitori,
# quindi nell'attività di caregiver,
# le chiederai,
# quindi di concentrarsi sulle persone,
# le quali ha fornito gratuitamente,
# suporto aiuto negli ultimi 12 mesi.
# OK?
# Quindi nell'ultimo anno,
# le persone ha dato in modo gratuito suporto.
# Questo può essere un suporto anche
# per un brevissimo periodo, OK?
# E queste persone oggi anche potrebbe
# non supportare più,
# quindi le chiederai noi di queste persone
# e il tipo di supporto che ha dato.
# Io già una griglia dei tipi di supporto
# e poi la vediamo assieme a un po' questa griglia.
# Quindi,
# nascitutto abbiamo i genitori,
# prisco e alfonso.
# Quindi,
# sono i fili,
# i miei fili sono,
# io ho dovuto,
# ovviamente,
# supportarli,
# essendo due gemelli di 15 anni.
# Io, tra l'altro,
# ho una zenda e quindi ho 10 dipendenti.
# Quindi,
# mi accumbi un po' di tante
# persone.
# E in queste 10 mesi,
# ho anche un tessuto di amiche,
# quindi che,
# anche solle motivamente supporto,
# ci supportiamo.
# E...
# Grazie.
# Questo essendo un post-andardizzo.
# La devo compilare così un troppo.
# Allora, diciamo che i suoi titori
# ha dato del demaro.
# Spligo?
# Sicuramente,
# in oltre i miei genitori,
# quali sono copata,
# i miei fili.
# Mi può dire il nome.
# E i fili,
# Giovanni Paolo e Martina.
# Martina?
# Ok.
# E poi chi altro ha dato,
# diciamo,
# un aiuto,
# un supporto,
# negli ultimi 12 mesi?
# Ma to' emotivo.
# E...
# Anche delle mie ara ne mi castiglia,
# a mio marito,
# che ha persi genitori un anno fa,
# quindi...
# E motivamente,
# mi sono indagata in tante,
# su tante persone,
# ingaggiata.
# Sì.
# Consochiedere il nome di suo marito,
# anche.
# Proberto.
# Proberto.
# Ok.
# E...
# Diciamo,
# allora, i suoi genitori ha dato aiuto
# in demaro,
# o duramente,
# oteriale.
# Sì.
# Ma, suporto fisico,
# sicuramente,
# materiale,
# organizzativo,
# e ogni tanto,
# anche economico.
# Ok.
# E inforzioni ha passato i suoi genitori,
# su magari anche le condizioni di salute,
# informazioni...
# Non ho capito la domanda,
# mi perdoni.
# Ok.
# Se ne ha dato aiuto anche dal punto di vista
# dell'informazione e suoi genitori,
# ha passato magari delle informazioni,
# sulle condizioni di salute,
# su condizioni,
# ma anche delle abitazioni.
# Sì, sì,
# loro sono abbastanza ancora attivi.
# A partenmi papà che mi ha dato di Alzheimer,
# ma è ancora presente.
# La mamma,
# a parte questo episodio,
# fisico, alginocchio,
# mentalmente,
# è molto lucida,
# ancora gestisce le cose.
# Beh,
# io,
# le pago con sulle bollette,
# queste cose,
# qualche pellele,
# non ha neanche più vogliamentalmente di seguire,
# c'è,
# fa fastica,
# sta dietro la burocrazia delle cose,
# ma do anche informazioni che so,
# c'è da fare questa cosa,
# ma la modalità,
# fare la ragnione condomiale,
# bisogna andare a rinocominare,
# per capire cosa sta succedendo,
# piuttosto che,
# ma, ma,
# o papà,
# guardate che abbiamo le visite,
# quindi ho tutto un calender,
# dove,
# se discuti gli appuntamenti per loro,
# gli ricordo,
# e,
# i pubi possono ancora fare delle cose loro,
# dove non le possono fare,
# li facciamo insieme.
# Ecco,
# come papà è,
# non è più un rapporto padre figlio,
# ma è diventata figlia,
# figlio,
# c'è nel senso che,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# si,
# slot.
# che le posso che può aiutare il strumento?
# Ma facendo questa settimana, ho contattato venerdì gli assistenti sociali del
# comune per capire se c'era la possibilità di avere una Utah casa per la mamma, perché
# non potendo camminare e lei deve mangiare a pranzo, lavoro lontana e quindi ho
# pensato dai servizi sanitari sociali, cioè del comune, qualcuno che venga a
# casa che le faccia mangiare, quindi martedì al colloco e con l'assistente
# sociali per capire quali servizi pitò il mettere in atto e mettere in
# protezione la mamma in questo momento papava già il centro di Urno Anziani, anche
# lui lo messo in protezione, quindi la mattina lo vengono a prendere a casa, lo portano
# al centro Anziani, dove fanno le loro attività e per riturna alle 4-1-4 e
# quindi siamo solucita, grazie servizi, introdotti proprio anche dalla
# cybercafe, a capire che ci sono tutta una serie di aiuti che a cui si può
# attingere nei momenti di difficoltà, perché comunque non è facile gestire
# due genitori, gestire due genitori in generelle, è col somo, dovendo si dedicare
# anche al lavoro, c'è rimanato di successi, e quindi lei ha dato anche su porto
# di consigli, sostegno morale, psicologico e genitori assolutamente da come
# a si espressa, altri sostegni, altri aiuti?
# Allora, l'anno scorso quando venifagodio mentre preso l'alzema e caffè per papà all'inizio,
# le cordi latrici di questo centro hanno dato supporto psicologico a mia mamma, quindi
# e anche di alla verità ogni tanto, ho un psicologo con il mi rivolgo dove sono
# nei picchi massimi di fatti di giornal, che adesso dove sono nei picchi massimi di
# indicare quel motivo mi rivolgo a questo psicologo proprio per riorganizzare la
# parte emotiva, mettere in ordine, come dico io devo mettere in poi in ordine la
# cassetta degli attrezzi, perché se no ma, ok quindi mi sembra che sui genitori
# ci siamo, invece su le altre persone che mi ha indicato Paolo, Giovanni Paolo, Martina, Roberto
# e Silvia, che aiuti, mi fratello, lui non è preso in più, una cosa che ci dispiace anche
# che non si l'indeguarda, quindi siamo sulle domande, sulle persone che lei aiuta, che aiuta
# il mio valuto, ok, quindi mi dice, Paolo e Martina, rispetto ad un'ipaolo, rispetto
# a queste iutistane di Giammarro, Giovanni Paolo e Martina sono i miei due figli, quindi
# devo supportare e assistere emotivamente perché stanno affrontando alla scuola, stanno
# iniziando una fase di crescita dove hanno anche loro delle esigenze, quindi supporte
# economico, supporto soprattutto morale a cui tengo molto e psicologico, c'è in senso
# motivarli, dati delle regole anche a abbastanza, c'è non perfessinismo, c'è in senso due
# devono, secondo me, è giusto che ci senti le regole, sono un genitore non sono un amico
# e quindi un carico a volte si prendano molti conflitti e non sempre facile, a volte anche
# avere, a volte vengono la pita delle emozioni per esbrocco perché è suma, non è il carico
# è motivo importanti, il genitore, l'agessione è pari per la sera con una banalità,
# voglio andare a 15 anni in un locale, no, e quindi sono questi conflitti a volte, però
# se spino, te lo sono sempre stati gestiti tranquillamente, è una amica sì, è una amica
# che ho una amica da quando ci conosciamo quando avevamo 11 anni, andavamo alle medie
# insieme, ho rapporto quasi di fraterno, di fraterno sorelle e purtroppo c'è un
# catalizzatore un po' di cose, a Sibia diciamo che non dà un supporto in monetario, in
# denaro, più che in supporto, magari è motivo, sì, ok, tornando un attimo ai figli,
# passa anche dell'informazione, secondo me da come mi diceva anche sullo stile di vita,
# quanto vi sembra davvero, sì, sì, sì, per quanto riguarda le reputazioni, le credenziali,
# per i figli, dato un supporto, anche conoscenze interpersonali, le aiuta intrati delle
# reti, magari non soli reti di vicinato, le reti comunitari della parrocchia,
# allora loro questi entrambi stanno facendo un percorso, un perfor, alloratorio,
# per corsiado, per dedicati agli adolescenti alla sera, il venerdì sera, vanno lì e lo
# angagiati, etc. Stanno un po' le interdure i figli, qui, assolutamente, assolutamente,
# a dire la verità non è che io ho consigliato, è stata una condizione se ne conoscono, volete
# fare dell'altro, però mi ha contentato e fate anche questo, perché secondo me il tessuto
# sociale va anche indottrinato, e quindi anche se a volte non ci vanno e che se non ci voglio
# non andare, ho detto che però queste state voglio che voi facciate all'oratorio, perché
# se no, a casa cosa fate, se ti ha mutato i viagliornati senza costruire niente, e allora
# profitto ho che andate all'oratorio, ma per poter andare all'oratorio e fare gli animatori,
# dovete fare un percorso ovviamente formativo prima. E quindi abbiamo fatto negoziato questo
# accordo. E ritornando poi a la sua mica Silvia, dai ultimateriali anche a la sua mica Silvia.
# No, materiali no, no, materiali no. I formazioni ne ha pazzato magari informazioni generali.
# Sì sì, le stacco percorso che sto facendo i figli, a casa vuoi che anche lei è una ragazza
# della stessa età di mia era i ragazzi, quindi siamo rimasti incinti il fieme, e quindi
# anche lei stava facendo fare la sua figlia, lo stesso percorso ma in un altro oratorio,
# perché è in un altro comune, però diciamo che ci parla elamente e facciamo lo stesso percorso.
# E rispetto le riputazioni le credenziali con la sua mica Silvia, non so, ha mai passato
# un contato di una persona che la sua mica Silvia ha contattato a nome su. No, no, no, no,
# è anche me abbastanza ingaggiata anche lei una prossima oltre in gamba.
# E rispetto le conoscenze ha presentato Silvia qualcuno che entrava la sua reita che poi l'ha
# aiutata o diciamo che è stato autonoma anche Silvia. Nel passato sì, nel passato sì,
# questi ultimi 12 mesi no. No, no, no, no, no, no, no, più supporto su tutta la linea,
# più un supporto emotivo e direci per quel rispetto. Ci siamo sposati da due anni praticamente,
# quindi ci conosciamo da 10 e abbiamo deciso due anni fa di sposarci e quindi insomma, proprio
# perché papà non stava bene e ben detto prima che papà non si può sassister a questo evento,
# visto che prima, ma proprio per centrami di genitori, incivete cinque mesi in di seguito
# il covid, adesso facciamo lo subito e quindi poi dà appenduto per fare i quanti i luti accumulati.
# E quindi aiuti materiali diciamo su marito informazioni no, queste non...
# Ho approvato, ho ingaggiarlo perché ripeto, secondo me, in certi contesti bisogna farse
# evitare, sono delle idee che si non fa, ma la genocchio da loro topedi, che se uno amare
# alla testa va da neurologo, se uno amare a di pensieri, diventando il psicologo perché
# deve basta soltanto riassettare un attimino il format e lo ha ingaggiato, tra l'altro
# avevamo fatto, avevamo avuto impassato, avevamo fatto un percorso insieme perché alberto
# non Roberto, alberto è il mio marito, ma non è il papà di i miei figli è stato introdotto
# non fa nella mia vita e quindi mi figli inizialmente il mio figlio, Giovanni Paolo inizialmente,
# aveva accettato, aveva avuto un conflitto e quindi avevamo già andati da lo stesso psicologo
# per facciutare a elaborare un po' di passaggi, che poi avevamo appunto grazie di io e all'insieme
# dell'informazione, diciamo di l'informazione, puoi siamo riusciti a portare a casa il risultato
# e adesso siamo un equilibrio perfetto, però è una cosa, il supporto emotivo è una cosa
# che ti lo devi sentire, non è anche se io posso ingaggiare, posso sollicitare, posso
# come dire, invitare a farlo, se non parte da te non è labora.
# E rispettare pudazioni credenziali e contatti conoscenze a suo marito ne ha passati.
# Ha contrario più lui e me che io a lui.
# Ok, nessun problema, diciamo così.
# Ah, qualche altra persona che ha sostenuto in questi ultimi 12 mesi che ha dato un aiuto,
# di questo tipo, insomma, adesso ha visto gli aiuti, no, in questo momento, no, in questi
# sono le persone più mistrette a me.
# Ok, allora passerai alleità di queste persone, si, mi può edare leità, il genero in
# questo, ma dai nomi, lo colgo anch'io, lo colgo, Martina, pardono, in questa scheda
# qualmi ha successo in qualcosa, ma faccio subito così, Martina, in tanto se lei pensa
# alleità di queste persone e me le può dire.
# Giovanni Paolo 15, Silvia 48 al Berto 55.
# Perdò, allora, mi ha successo qualcosa qui, no, poi controllo io, i puoi ripetere leità.
# Allora, Giovanni Paolo 15, Martina 15?
# Sì, infatti queste mi aveva accennate prima, giusto a me.
# Ok, poi, Silvia, non vedo, non riesco a vedere lì, ok?
# Berto, scusi?
# 55?
# 55 e Silvia 48.
# 48, ok.
# Mi serverebbe anche il titolo di studio dei genitori.
# Mi sentireanno le elementari?
# Ok, aspetti, prisco suo Paolo scrivo perché mi è successo qualcosa.
# E' sua mamma era Alfonzina, Alfonzina, allora, leità di genitori me la dita prima,
# quindi me la copio io, licenza elementare i suoi genitori, allora, con la quale licenza
# elementare, i figli hanno titolo di scuola media, quindi...
# Non facendo, sì, sono i verori a più.
# Sì, il marito al Berto?
# Di Ploma?
# Di Ploma che permette l'accesso all'università, o non...
# Ok.
# E la sua amica Silvia?
# E invece penso che avrei studi professionali, non credo abbia finito la scuola...
# No, non ha fatto allo di Ploma, ha fatto degli professionali.
# E che non permette l'accesso all'università?
# Allora, questi qua sono, parente non convivvente, con lei, i genitori, porti pazienza,
# abbiamo tutta questa scheda da compilare, parente, familiare, diverso del partner, con
# vivente con lei, sono i figli, è il partner, con vivente con lei, e invece...
# Marsilvia è una amica.
# Lei sta aiutando queste persone in questo momento qua, il genitorio assolutamente,
# i figli mi diceva di sì.
# Il marito le sta aiutando in questo periodo su un marito o è...
# È una piore che ha aiuto un'ilaterale, è un supporto bilaterale in Trambi.
# E la sua amica Silvia, la sta aiutando, sta fornendo supporto anche in questo periodo
# nella vita quotidiana.
# Adesso, in questo periodo occuto in cui mi aveva messato il recuperata, no?
# Però, come si dice, normalmente ci supporta la supporto spesso, ci sono un po' di contesti
# particolari.
# Indine, nel gli ultimi 12 mesi, diciamo, che lei sta dando supporto a queste persone
# qui.
# In gli ultimi 12 mesi le state il carghiver dei suoi genitori.
# Ad il carghiver, ok, mentre delle altre persone, no, ma questo lo compilo io dopo,
# anche per non portarle via del tempo, perché insomma, vola le carghiver di questa persona
# anche in questo periodo qua, si diciamo le altre notte, le tipi di problemi che aveva,
# che hanno i suoi genitori insomma, sono dovute l'invecchiamento, problemi dovute
# apatologie croniche, dovute addisabilità.
# Papa, invecchiamento, perché appunto gli hanno riscontrato l'alzheimer.
# E la mamma?
# E anche due più risposte.
# La mamma invece, invecchiamento, in questa patologia, speriamo momentani,
# quindi comunque le carghiver invecchiamento.
# Ok, lasciamo l'ora invecchiamento, lasciamo.
# Adesso, invece, passerei alla sezione degli aiutti che lei riceve, e quindi le chiederei
# sempre rispetto alla scermata di prima che l'ha fatto vedere se indica il nome delle persone,
# diverse da quelli di cui abbiamo parlato, alle quali lei ha dato supporto, le quali
# le aiutato in questi ultimi 12 mesi, anche per un brevissimo periodo, ok?
# No, no, in cui sono queste persone qua.
# Ok.
# E lei ha ricevuto supporto da altre persone diverse da quelli che abbiamo, ok?
# Mi potrebbe in i cari nomi di Christian?
# Allora, possiamo...
# Beh, sicuramente l'alzheimer caffè mi ha dato la mano, quindi...
# E' una persona che mi può indicare il nome di Christian?
# L'ora, la corgola, l'ora.
# L'ora, ok?
# Questa cosa?
# Sto pensando se gli assistenti sociali in Barbara Minervino?
# Barbara?
# Vasta.
# Solo queste due.
# Che tipo di supporto le ha dato?
# Ritodenaro.
# No, no, no, no, no, solo organizzativo, anche di come gestire appunto la malattia del
# papà, come gestire i problemi della mamma e via.
# Quindi direi un aiuto di tipo informativo?
# Si, si.
# Metto gestione qui.
# No, le hanno fornito altri contatti di persone che magari le ha posti.
# Si, si, si, anche.
# Me hanno anche solo, si, me hanno fornito anche i contatti per poter contattare le persone
# per avere informazioni operative, piuttosto che anche di supporto.
# Si, si, è soltamente.
# Le hanno fornito anche un supporto morale psicologico.
# Si, assolutamente, si.
# Entrambe queste persone.
# Si, entrambe, entrambe.
# E le hanno passato anche dei contatti magari non so.
# L'hai contattato qualche medico, qualche professionista per conto di queste persone.
# Oppure era più un aiuto.
# No, in questo ambito no, no.
# Ok, no.
# Perfetto.
# Ok, allora adesso le chiederai indicativamente anche delle informazioni,
# socio-demografica su queste persone.
# Stai leità di queste persone, non so se.
# Non è l'altro molto indicativo.
# Posso dire le stupereore ai 40 anni.
# Una Laura inturora cinquantina e 3.40, 5.50 e Barbara 3.40 e 45.
# Questo posso guidarle.
# Non solo la loroità.
# Mettiamo a 43, allora.
# Il studio ha un'idea del titolo di studio di questi settori.
# Tanto che siano tutte due laureate,
# perché è un assistente sociale e l'altro psicologo,
# quindi sicuramente le laureate.
# Le relazioni che hanno sono altro,
# quindi possiamo dire esperti nel settore.
# Mi variabbe da dire.
# Si, si.
# Ok, annulla.
# Perché non devo prendere l'ultima riga?
# Perdone.
# Ok.
# Non me lo dava.
# Meno segno io dopo insomma.
# Ok.
# Ome la sta aiutando anche in questo periodo oppure no.
# Sì, sì, sì, sì, soltamente.
# Ok, sì.
# Sì.
# Perfetto.
# Allora, adesso le chiedereai un aspetto un po' particolare.
# Questo è persone qui.
# La stanno si aiutano tra di loro.
# Desso non so se vede questa scheda qui,
# però non è importante.
# Io le dirò i nomi.
# Quindi negli ultimi 12 mesi sono esistiti
# dei legami di supporto o aiuto.
# E quindi in caso di bisogno del corso della vita quotidiana,
# tra le persone che ha menzionato e verso di lei,
# da parte di quelle che l'ha aiutato.
# Sasse queste si sono aiutate e si conoscono a vicenda.
# Non ti conoscono, no?
# Non c'è una relazione, il punto di contatto sono io,
# ma sono due modi separati.
# Ok.
# Però diciamo che
# tra
# il suo apa
# non l'ha fornito supporto,
# perché lei che fornice supporto il suo apa.
# E anche sua mamma non l'ha fornito supporto.
# Ok.
# Ok.
# Perché il suo apa?
# Giovanni Paolo forniscono supporto a lei i suoi figli.
# Si?
# Si, quindi questo si e anche Martina credo,
# come Roberto,
# le fornisce e anche Silvia e il supporto.
# Ok.
# Alfonso,
# no, prisco.
# Non so perché non mi ha preso le
# in automatico i nomi.
# E tra
# alfonso, alfonzina non credo che ci sia su pao aiuto.
# Per qui?
# Si.
# Ma mamma supporta tanto,
# mi papà e mi papà in quei momenti di supporta anche mi amo.
# Riesce allora.
# Riesce anche su.
# Motivamente, si.
# Si.
# E i nonni aiutano anche i nipoti diciamo.
# Si, si, si.
# Perché più in verso hanno aiutato i nipoti adesso i nipoti aiutano i nipoti.
# Sono i nipoti.
# Allora, si.
# Quindi diciamo che i nonni non danno,
# non riescono a dare un supporto.
# I più ultimi 12 mesi sono i nipoti che aiutano i nipoti.
# Si, si.
# E neanche alle ai tecnici diciamo del caffè in un assistente sociale.
# È fatto.
# Alfonzina mi ha detto che aiuta su pao.
# Con i poti diciamo, no, sono i nipoti che danno.
# Ops, che danno sostegno.
# No, anche qui.
# No.
# Allora, i nipoti diciamo.
# Allora, questo caso Giovanni Paola aiuta a i nonni.
# Si.
# Giovanni Paola da un supporto anche Martina.
# No.
# No, non sono ancora abbastanza.
# Sono una fase delle facciamo da soli.
# E ad Alberto da un supporto.
# Alberto, non supporto i ragazzi, ragazzi.
# Beh, ai a loro modo aiutano anche Alberto.
# Quindi c'è un supporto reciproco.
# Con la sua mica silvia però non credo.
# No, no, esatto.
# È un po' il colante, ok?
# Esatto.
# Martina aiuta in onni.
# Si.
# Giovanni anche il fratello.
# Martina oppure non.
# E come il fratello?
# Puoi fare copi in colla la solita di Giovanni Paolo e coperla su Martina.
# Piava però forse era in decisa prima.
# Non molto.
# Non si convinto.
# Mi sembrava.
# No, ma perché sono ancora nella fase.
# Si aiutano, ma poi non si aiutano.
# Non ci sono le buon intenzione, ma non ci sono poi fatti.
# Ok.
# Ok.
# Metti a mano qua.
# Invece, Alberto aiuta ai suoi genitori o.
# I suoi genitori.
# No, magari non ne mutiamo.
# Beh, non agli aiuta aiuta.
# È sempre pronta a trovarti le soluzioni anche lui.
# Si.
# Anche con i figli con la sua mica però non credo che ci siano.
# No, meno relazione, meno relazione.
# C'è mi incitiamo.
# Certo.
# Con l'alzheimer caffè con l'aura dell'alzheimer caffè con Barbara non ha.
# Nessuno conto.
# Ok.
# Silvia.
# E con i suoi genitori a contatti Silvia non.
# No, no, no.
# No, in questo momento non.
# Con i figli invece riesce Silvia da un supporto.
# Una aiuto in caso del bisogno anche i figli.
# Vite il posto di bisogno assolutamente.
# Si, si, si.
# E negli ultimi 12 mesi c'è stato un supporto.
# No, no, no.
# Ok.
# No.
# No.
# No.
# E con Alberto il ultimito 12 mesi mi sembrava che dicesse di no.
# No.
# Si.
# D'accordo.
# Sì.
# D'accordo.
# D'accordo.
# E neanche con le assistenti sociali.
# E le assistenti sociali aiutano lei in partito.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# D'accordo.
# Siete? Sono una persona che...
# Ok. E' utilizzando la scala di valore quanto si fila
# complessivamente del sistema politico-democratico.
# Politico-democratico un po' meno sono sul sei,
# sono proprio perché al cidevi comunque essere un rientamento a questo,
# quindi sul sei.
# E sul sistema economico complessivamente del sistema economico
# Il bufינolet Break Generali ha fatto che esté fondateli
# e che mi vedono in questo periodo storico nel mondo, ecclo?
# Spara fur הב�oowello.
# Ok. Allora, perfetto. Passarai quindi all'ultima sezione che sono le demande socialdemogranse.
# credere chi è il vendito su tratto di studio.
# Di próma all'università per l' Experimento
# impresa quindi lei è lavoratore in prontio e soci dell'azienda, si però è non è
# dipendente e quindi libro professionista, no no no sono prenditrice, prenditrice esatto,
# giana artigiana con dipendenti o in prenditrice, prenditore quindi in prenditrice, ok lasciamo
# questo e da quante persone composto suonucro mi sembra quattro suonucro familiare che mi diceva
# sì, ok e vive quindi con coniuge e avete figli, le agitalienze italiana, l'ultima domanda riguarda
# il reddito mensile, qua siamo sulle fasce fino a 1.000 euro, da 1.100 a 2.000 euro, da 2.100 a 4.000
# euro, oltre i 4.000 euro, da 2.100 a 4.000 euro, ok perfetto, allora questa qui come le diceva appunto
# e la ringrazie per questo tempo riguarda la struttura delle sue areti ed era una parte insomma
# dell'intervista perché l'intervista è un postandardizzata come ha visto abbiamo domande standardizzate
# allora adesso questa posto interrompere è la condivisione, il secondo step della ritorno sui
# il mio schermo, del dell'intervista sarebbe un'intervista discorsiva aperta, ci raccontava però sarebbe
# un'intervista in modalità di adica, ok quindi da fare anche con un'altra persona e la persona
# da identificare sarebbe la persona creda più supporto in questo momento, in questo momento
# diciamo che la persona è più supporto sono e mi è marito che in questo momento però non c'è
# non non un questo momento fare l'intervista, in generale si stino dico, qui dicamente adesso mi
# avruttimmente che mi avrete di questa cosa si potevo coinvolgere una persona ma mi
# avevo adesso come l'aderto mi avevo l'intervista in mente, mi sono risolto, però
# io lo credo poi tutti le vicissitudes della settimana è comprensibile insomma, qui anche se vuole
# aggiungere qualcosa, hanno più sperienza di messo l'intervista di adica, però l'intervista di
# adica va fatta tra l'intervistatore e due persone, quindi vogliamo sapere, cioè sapere vogliamo
# così che il caregiver ci racconti la sua sperienza con anche la persona che supporta il caregiver e
# quindi servirebbe la persona creda più supporto identificare questa persona e poi una volta identificata
# questa persona ci fissiamo un appuntamento e sempre in zoom così registriamo l'intervista e poi
# noi raccogliate, domande, ok? Per cui c'è utile conoscere, quindi anche nome con nome o
# riferimento di mail dell'altra persona, perché proprio a fine della conclusione, della ricerca,
# inviaremo riconoscimento a chi ha partecipato insomma anche per ingraziarli dal tempo che
# hanno messo a disposizione queste persone qui, ok?
# Alberto, il mio marito, che adesso indirizzo me in questo momento mi sfugge, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no
# no, no, no, no, no, no, no
# ma se odio se è scappata, se è scollegata, se è sconnessa vediamo se si riconnette, c'è stato
# qualche ingipo nel file excel, non so perché anna e dopo roco di controllo, ma mi è che questa
# mattina ho provato a metterci mano, se vuole aggiungere qualcosa sull'intervista, ecco la qui
# che la mettiamo, se voglio aggiungere qualcosa sull'intervista di adic, lei anna che a più esperienze di
# me così raccontiamo un attimo a Fiorella, è assaltata la linea, ci scusi, sì sì sì sì no no siamo
# ancora qui, non so se anna vuole raccontare qualcosa di più sull'intervista di adic, per quelle
# servirà magari adesso abbiamo impiegato un po' misorita a 3 quarti d'ora per questo, per l'intervista
# servirà un po' più di tempo insomma perché quando si in cominci a parlare si raccontano le
# esperienze e questo veramente è in fondamentale per noi, quindi a mettere già in preventivo più di
# un oretta, ok, un ore mezza ok, ma bene, ma bene, ma bene, certo, poi di organizzare in loro
# arro in cui possiamo dedicare quali fai il devore, sì anche più tardi se per voi è più comodo,
# ok, tanto io come il cercatore ha la disponibilità insomma sono flessibile non ho problemi, ok,
# non so se anna vuole aggiungere qualcosa oppure, cioè scegliere un'intervista di adic, invece
# un'intervista singola ci aiuta, ci aiuta a capire le mellole relazioni, a capire un due punti di vista
# e le relazioni, quindi questo è importante, cosa che non sarebbe possibile con un'intervista,
# e non sarebbe possibile neanche con due intervista singolesi, ci fa vedere un'intervista di adic,
# delle cose che non riusciremo a vedere con due intervista singoles o solo con una intervista,
# quindi vediamo, condivido capisco il punto di vista, ecco quindi l'altra persona però dovrebbe
# essere fisicamente proprio presente nella stanza, dovrebbe per creare quella dinamica di supporto
# di relazioni tra, ho capito chiaro, mi è molto chiaro, io dirai di sentirci in settimana per i
# meyla e così confermiamo magari per sabato prossimo, volentieri, noi la lasciamo, io rimango un
# attimo con Anna, se può, grazie ancora, pariamo che tutto proceda per il meglio per i suoi genitori,
# ecco e grazie di questa disponibilità. Grazie a voi, buon lavoro, a grazie, grazie, grazie, grazie, grazie.
# Grazie. Grazie allora, devo capire nel file cosa è successo, perché in questo file come è
# visto questa mattina le mani un attimo per fare le prove ancora, quindi si è sfasato, ha capito
# per un po' il meccanismo. Sì, sì, sì, sì, sì, no, era, diciamo che così è chiarissimo, raccontata,
# raccontata, invece che vista di retamente sembra molto più, molto complicata. La professoresse di
# dovevo mostrarla gli intervistati, però visto che c'era anche lei questa volta la mostrata, perché, però, forse,
# sì, secondo me uno come si organizza meglio, va meglio la persona come si organizza, perché poi vede
# non sto pensando, sto pensando in cosa può, in cosa può influire negativamente che è
# l'intervistato, se si fa vedere un foglio per volta in un tutto insieme, sto pensando cosa può, cosa può.
# Non saprei, perché come vede qua l'intervistata partiva andava, parlava, non seguiva un po' la standardazione.
# Usano il cellulare e quindi magari non vedono neanche bene il foglio, quindi sì, non è che abbia
# influito anche secondo me in questo momento qui, perché non seguono, loro raccontano gli aiuti che danno,
# difficili anche per loro in quadrarli, questa intervista qui sarebbe più riascarmo, si leggono a scarmo
# le domande e ognuno le compile, quindi così per loro è più difficile, è più.
# No, ecco, ha suggerimenti da dare anche sul mio modo di fare interviste o somministrare questa scheda
# Anna adesso, così ne ha profito per imparare e perfezionare.
# Per carità.
# No, no, no, direi che ha funzionato tutto.
# Sì, e poi bisogna stare un po' nei tempi, perché secondo me anche loro, almeno su cui è stati dedicare più tempo
# alla diadica.
# Sì.
# Sì, vi bisogna proprio lasciare parlare.
# Sì, sì.
# Quindi intanto.
# Vi dispiaceva interrompre l'intervistata perché anche l'inizio era partita raccontando gli aiuti che dava e che riceveva,
# ma bisognerebbe stare nella griglia e quando uno parla tempo vola e non vorrei portarvi a molto tempo,
# che poi si sta anche in linea di...
# Ah, sì.
# E quindi va beh.
# E' questo un po' il meccanismo, va bene?
# Sì, sì, va bene.
# Allora, io se posso prendere contatto con qualcuno vero di...
# Vi lo giro.
# Già oggi pomerì.
# Sì.
# Atto di qualsiasi.
# Sì, sì, sì.
# Così mi ci ho chiedere se...
# Se e quando?
# Perché guardi, c'era stata, già una persona che mi aveva scritto di essere...
# Vabbè che l'avevo contattato io la settimana prossima.
# Vediamo come si chiama questa persona qui.
# E' un attimo solo ricerche, non divenetica, quassa croquore.
# E' restata ritta.
# Questa spessione...
# Qua mi dice, mi può contattare?
# Tutti i giorni, face oraria, dalle quattordice, le dice a sette.
# Potrei risponterle mettendo in Cicilei che la contatera lei e che se ne occuperà lei...
# Sì, sì, direi di sì dire che va benissimo.
# Ok, perfetto, dai.
# Allora, le mando subito questo contatto.
# E poi noi c'era giorni a me.
# Sì.
# Sì.
# Sì.
# Sì, no bene.
# Ok, allora posso interpretare la registrazione?
# Sì.

# %%
# !whisper 'GMT20240316-153653_Recordingconverted.wav' --model base --fp16 False --language it
# Out:
# [00:00.000 --> 00:07.840]  per me vedere i dati. Le posso chiedere anche la sua età Comune di Residenza,
# [00:07.840 --> 00:10.200]  nome della provincia di Residenza.
# [00:10.200 --> 00:12.920]  Allora, ho 49 anni,
# [00:12.920 --> 00:15.400]  resiega Bucinasco,
# [00:15.400 --> 00:17.600]  in provincia di Milano,
# [00:17.600 --> 00:24.000]  e ho due genitori di 82 e 83 anni.
# [00:24.000 --> 00:26.960]  82 sarebbe il papà.
# [00:26.960 --> 00:29.400]  82 la mamma, aluglio,
# [00:29.400 --> 00:31.400]  e papà, settembre,
# [00:31.400 --> 00:34.400]  ho 49, 84.
# [00:34.400 --> 00:36.400]  OK,
# [00:36.400 --> 00:39.400]  82 e 84, il papà.
# [00:39.400 --> 00:41.400]  E sono entrambi genitoriche,
# [00:41.400 --> 00:42.400]  lei assiste,
# [00:42.400 --> 00:43.400]  secco,
# [00:43.400 --> 00:44.400]  assiste, sembaglio,
# [00:44.400 --> 00:45.400]  mi raccontava, si.
# [00:45.400 --> 00:46.400]  Posso chiedere il nome,
# [00:46.400 --> 00:48.400]  allora delle persone che assiste,
# [00:48.400 --> 00:50.400]  nome del papà e della mamma.
# [00:50.400 --> 00:52.400]  Disco e mamma alfonsa.
# [00:52.400 --> 00:54.400]  Scusi, non ho capito il papà.
# [00:54.400 --> 00:57.400]  Prisco, come settere di Roma.
# [00:57.400 --> 00:59.400]  OK, e la mamma.
# [00:59.400 --> 01:01.400]  Alfonsa.
# [01:01.400 --> 01:03.400]  Alfonsa.
# [01:03.400 --> 01:05.400]  OK,
# [01:05.400 --> 01:07.400]  potrei condividere anche adesso,
# [01:07.400 --> 01:09.400]  magari la condivido, la tabella,
# [01:09.400 --> 01:10.400]  che sto compilando,
# [01:10.400 --> 01:12.400]  lei non prenda paura per la tabella,
# [01:12.400 --> 01:14.400]  sono molto domani,
# [01:14.400 --> 01:15.400]  ma inserirletti.
# [01:15.400 --> 01:16.400]  I genitori,
# [01:16.400 --> 01:20.400]  quindi risidono sempre a Bucinasco.
# [01:20.400 --> 01:22.400]  Sì.
# [01:27.400 --> 01:30.400]  È sempre in provincia di Milano.
# [01:30.400 --> 01:33.400]  Sì.
# [01:33.400 --> 01:41.400]  E lei,
# [01:41.400 --> 01:45.400]  sui genitori sono,
# [01:45.400 --> 01:49.400]  partenno conviventi con, non,
# [01:49.400 --> 01:51.400]  non è partenno convivente con lei,
# [08:07.080 --> 08:11.900]  protezione la mamma in questo momento papava già il centro di Urno Anziani, anche
# [08:11.900 --> 08:17.400]  lui lo messo in protezione, quindi la mattina lo vengono a prendere a casa, lo portano
# [08:17.400 --> 08:22.680]  al centro Anziani, dove fanno le loro attività e per riturna alle 4-1-4 e
# [08:22.680 --> 08:28.080]  quindi siamo solucita, grazie servizi, introdotti proprio anche dalla
# [08:28.080 --> 08:33.840]  cybercafe, a capire che ci sono tutta una serie di aiuti che a cui si può
# [08:33.840 --> 08:41.040]  attingere nei momenti di difficoltà, perché comunque non è facile gestire
# [08:41.040 --> 08:45.960]  due genitori, gestire due genitori in generelle, è col somo, dovendo si dedicare
# [08:45.960 --> 08:53.880]  anche al lavoro, c'è rimanato di successi, e quindi lei ha dato anche su porto
# [08:53.880 --> 08:58.600]  di consigli, sostegno morale, psicologico e genitori assolutamente da come
# [08:58.600 --> 09:05.200]  a si espressa, altri sostegni, altri aiuti?
# [09:05.200 --> 09:11.760]  Allora, l'anno scorso quando venifagodio mentre preso l'alzema e caffè per papà all'inizio,
# [09:11.760 --> 09:18.120]  le cordi latrici di questo centro hanno dato supporto psicologico a mia mamma, quindi
# [09:18.120 --> 09:24.960]  e anche di alla verità ogni tanto, ho un psicologo con il mi rivolgo dove sono
# [09:24.960 --> 09:30.040]  nei picchi massimi di fatti di giornal, che adesso dove sono nei picchi massimi di
# [09:30.040 --> 09:38.160]  indicare quel motivo mi rivolgo a questo psicologo proprio per riorganizzare la
# [09:38.160 --> 09:43.320]  parte emotiva, mettere in ordine, come dico io devo mettere in poi in ordine la
# [09:43.320 --> 09:49.560]  cassetta degli attrezzi, perché se no ma, ok quindi mi sembra che sui genitori
# [09:49.560 --> 09:54.920]  ci siamo, invece su le altre persone che mi ha indicato Paolo, Giovanni Paolo, Martina, Roberto
# [09:54.920 --> 10:04.040]  e Silvia, che aiuti, mi fratello, lui non è preso in più, una cosa che ci dispiace anche
# [10:04.040 --> 10:09.400]  che non si l'indeguarda, quindi siamo sulle domande, sulle persone che lei aiuta, che aiuta
# [10:09.400 --> 10:15.600]  il mio valuto, ok, quindi mi dice, Paolo e Martina, rispetto ad un'ipaolo, rispetto
# [10:15.600 --> 10:21.560]  a queste iutistane di Giammarro, Giovanni Paolo e Martina sono i miei due figli, quindi
# [10:21.560 --> 10:28.000]  devo supportare e assistere emotivamente perché stanno affrontando alla scuola, stanno
# [10:28.000 --> 10:33.080]  iniziando una fase di crescita dove hanno anche loro delle esigenze, quindi supporte
# [10:33.080 --> 10:38.320]  economico, supporto soprattutto morale a cui tengo molto e psicologico, c'è in senso
# [10:38.320 --> 10:46.000]  motivarli, dati delle regole anche a abbastanza, c'è non perfessinismo, c'è in senso due
# [10:46.000 --> 10:51.240]  devono, secondo me, è giusto che ci senti le regole, sono un genitore non sono un amico
# [10:51.240 --> 11:00.940]  e quindi un carico a volte si prendano molti conflitti e non sempre facile, a volte anche
# [11:00.940 --> 11:07.160]  avere, a volte vengono la pita delle emozioni per esbrocco perché è suma, non è il carico
# [11:07.160 --> 11:11.580]  è motivo importanti, il genitore, l'agessione è pari per la sera con una banalità,
# [11:11.580 --> 11:20.280]  voglio andare a 15 anni in un locale, no, e quindi sono questi conflitti a volte, però
# [11:20.280 --> 11:25.560]  se spino, te lo sono sempre stati gestiti tranquillamente, è una amica sì, è una amica
# [11:25.560 --> 11:30.440]  che ho una amica da quando ci conosciamo quando avevamo 11 anni, andavamo alle medie
# [11:30.440 --> 11:36.500]  insieme, ho rapporto quasi di fraterno, di fraterno sorelle e purtroppo c'è un
# [11:36.500 --> 11:44.260]  catalizzatore un po' di cose, a Sibia diciamo che non dà un supporto in monetario, in
# [11:44.260 --> 11:53.580]  denaro, più che in supporto, magari è motivo, sì, ok, tornando un attimo ai figli,
# [11:53.580 --> 11:59.260]  passa anche dell'informazione, secondo me da come mi diceva anche sullo stile di vita,
# [11:59.260 --> 12:06.100]  quanto vi sembra davvero, sì, sì, sì, per quanto riguarda le reputazioni, le credenziali,
# [12:06.100 --> 12:11.100]  per i figli, dato un supporto, anche conoscenze interpersonali, le aiuta intrati delle
# [12:11.100 --> 12:16.940]  reti, magari non soli reti di vicinato, le reti comunitari della parrocchia,
# [12:16.940 --> 12:23.380]  allora loro questi entrambi stanno facendo un percorso, un perfor, alloratorio,
# [12:23.380 --> 12:29.940]  per corsiado, per dedicati agli adolescenti alla sera, il venerdì sera, vanno lì e lo
# [12:29.940 --> 12:36.060]  angagiati, etc. Stanno un po' le interdure i figli, qui, assolutamente, assolutamente,
# [12:36.060 --> 12:41.900]  a dire la verità non è che io ho consigliato, è stata una condizione se ne conoscono, volete
# [12:41.900 --> 12:46.140]  fare dell'altro, però mi ha contentato e fate anche questo, perché secondo me il tessuto
# [12:46.140 --> 12:54.620]  sociale va anche indottrinato, e quindi anche se a volte non ci vanno e che se non ci voglio
# [12:54.620 --> 12:58.900]  non andare, ho detto che però queste state voglio che voi facciate all'oratorio, perché
# [12:58.900 --> 13:05.620]  se no, a casa cosa fate, se ti ha mutato i viagliornati senza costruire niente, e allora
# [13:05.620 --> 13:09.220]  profitto ho che andate all'oratorio, ma per poter andare all'oratorio e fare gli animatori,
# [13:09.220 --> 13:15.420]  dovete fare un percorso ovviamente formativo prima. E quindi abbiamo fatto negoziato questo
# [13:15.420 --> 13:24.940]  accordo. E ritornando poi a la sua mica Silvia, dai ultimateriali anche a la sua mica Silvia.
# [13:24.940 --> 13:33.020]  No, materiali no, no, materiali no. I formazioni ne ha pazzato magari informazioni generali.
# [13:33.020 --> 13:39.780]  Sì sì, le stacco percorso che sto facendo i figli, a casa vuoi che anche lei è una ragazza
# [13:39.780 --> 13:45.260]  della stessa età di mia era i ragazzi, quindi siamo rimasti incinti il fieme, e quindi
# [13:45.260 --> 13:49.060]  anche lei stava facendo fare la sua figlia, lo stesso percorso ma in un altro oratorio,
# [13:49.060 --> 13:55.460]  perché è in un altro comune, però diciamo che ci parla elamente e facciamo lo stesso percorso.
# [13:55.460 --> 14:01.500]  E rispetto le riputazioni le credenziali con la sua mica Silvia, non so, ha mai passato
# [14:01.500 --> 14:09.340]  un contato di una persona che la sua mica Silvia ha contattato a nome su. No, no, no, no,
# [14:09.340 --> 14:13.540]  è anche me abbastanza ingaggiata anche lei una prossima oltre in gamba.
# [14:13.540 --> 14:21.420]  E rispetto le conoscenze ha presentato Silvia qualcuno che entrava la sua reita che poi l'ha
# [14:21.420 --> 14:25.980]  aiutata o diciamo che è stato autonoma anche Silvia. Nel passato sì, nel passato sì,
# [14:25.980 --> 14:38.580]  questi ultimi 12 mesi no. No, no, no, no, no, no, no, più supporto su tutta la linea,
# [14:39.140 --> 14:49.900]  più un supporto emotivo e direci per quel rispetto. Ci siamo sposati da due anni praticamente,
# [14:49.900 --> 14:58.100]  quindi ci conosciamo da 10 e abbiamo deciso due anni fa di sposarci e quindi insomma, proprio
# [14:58.100 --> 15:02.020]  perché papà non stava bene e ben detto prima che papà non si può sassister a questo evento,
# [15:02.020 --> 15:06.660]  visto che prima, ma proprio per centrami di genitori, incivete cinque mesi in di seguito
# [15:06.660 --> 15:14.740]  il covid, adesso facciamo lo subito e quindi poi dà appenduto per fare i quanti i luti accumulati.
# [15:14.740 --> 15:21.260]  E quindi aiuti materiali diciamo su marito informazioni no, queste non...
# [15:21.260 --> 15:26.220]  Ho approvato, ho ingaggiarlo perché ripeto, secondo me, in certi contesti bisogna farse
# [15:26.220 --> 15:32.220]  evitare, sono delle idee che si non fa, ma la genocchio da loro topedi, che se uno amare
# [15:32.220 --> 15:37.020]  alla testa va da neurologo, se uno amare a di pensieri, diventando il psicologo perché
# [15:37.020 --> 15:44.660]  deve basta soltanto riassettare un attimino il format e lo ha ingaggiato, tra l'altro
# [15:44.660 --> 15:50.620]  avevamo fatto, avevamo avuto impassato, avevamo fatto un percorso insieme perché alberto
# [15:50.620 --> 15:57.940]  non Roberto, alberto è il mio marito, ma non è il papà di i miei figli è stato introdotto
# [15:57.940 --> 16:04.180]  non fa nella mia vita e quindi mi figli inizialmente il mio figlio, Giovanni Paolo inizialmente,
# [16:04.180 --> 16:08.940]  aveva accettato, aveva avuto un conflitto e quindi avevamo già andati da lo stesso psicologo
# [16:08.940 --> 16:14.460]  per facciutare a elaborare un po' di passaggi, che poi avevamo appunto grazie di io e all'insieme
# [16:14.460 --> 16:18.900]  dell'informazione, diciamo di l'informazione, puoi siamo riusciti a portare a casa il risultato
# [16:18.900 --> 16:26.660]  e adesso siamo un equilibrio perfetto, però è una cosa, il supporto emotivo è una cosa
# [16:26.660 --> 16:33.460]  che ti lo devi sentire, non è anche se io posso ingaggiare, posso sollicitare, posso
# [16:33.460 --> 16:40.820]  come dire, invitare a farlo, se non parte da te non è labora.
# [16:40.820 --> 16:47.780]  E rispettare pudazioni credenziali e contatti conoscenze a suo marito ne ha passati.
# [16:47.780 --> 16:50.500]  Ha contrario più lui e me che io a lui.
# [16:50.500 --> 16:53.220]  Ok, nessun problema, diciamo così.
# [16:53.300 --> 16:58.020]  Ah, qualche altra persona che ha sostenuto in questi ultimi 12 mesi che ha dato un aiuto,
# [16:58.020 --> 17:06.180]  di questo tipo, insomma, adesso ha visto gli aiuti, no, in questo momento, no, in questi
# [17:06.180 --> 17:08.580]  sono le persone più mistrette a me.
# [17:08.580 --> 17:17.940]  Ok, allora passerai alleità di queste persone, si, mi può edare leità, il genero in
# [17:17.940 --> 17:31.780]  questo, ma dai nomi, lo colgo anch'io, lo colgo, Martina, pardono, in questa scheda
# [17:31.780 --> 17:41.460]  qualmi ha successo in qualcosa, ma faccio subito così, Martina, in tanto se lei pensa
# [17:41.460 --> 17:45.020]  alleità di queste persone e me le può dire.
# [17:45.580 --> 17:50.580]  Giovanni Paolo 15, Silvia 48 al Berto 55.
# [17:50.580 --> 17:55.940]  Perdò, allora, mi ha successo qualcosa qui, no, poi controllo io, i puoi ripetere leità.
# [17:55.940 --> 18:00.340]  Allora, Giovanni Paolo 15, Martina 15?
# [18:00.340 --> 18:04.020]  Sì, infatti queste mi aveva accennate prima, giusto a me.
# [18:04.020 --> 18:09.180]  Ok, poi, Silvia, non vedo, non riesco a vedere lì, ok?
# [18:09.180 --> 18:10.580]  Berto, scusi?
# [18:10.580 --> 18:12.580]  55?
# [18:13.580 --> 18:18.580]  55 e Silvia 48.
# [18:19.580 --> 18:21.060]  48, ok.
# [18:21.060 --> 18:28.540]  Mi serverebbe anche il titolo di studio dei genitori.
# [18:28.540 --> 18:31.100]  Mi sentireanno le elementari?
# [18:31.100 --> 18:40.820]  Ok, aspetti, prisco suo Paolo scrivo perché mi è successo qualcosa.
# [18:40.820 --> 18:51.020]  E' sua mamma era Alfonzina, Alfonzina, allora, leità di genitori me la dita prima,
# [18:51.020 --> 18:55.540]  quindi me la copio io, licenza elementare i suoi genitori, allora, con la quale licenza
# [18:55.540 --> 19:00.580]  elementare, i figli hanno titolo di scuola media, quindi...
# [19:00.580 --> 19:03.620]  Non facendo, sì, sono i verori a più.
# [19:03.620 --> 19:07.420]  Sì, il marito al Berto?
# [19:08.420 --> 19:10.420]  Di Ploma?
# [19:10.420 --> 19:14.420]  Di Ploma che permette l'accesso all'università, o non...
# [19:14.420 --> 19:15.420]  Ok.
# [19:15.420 --> 19:17.420]  E la sua amica Silvia?
# [19:17.420 --> 19:22.420]  E invece penso che avrei studi professionali, non credo abbia finito la scuola...
# [19:22.420 --> 19:26.420]  No, non ha fatto allo di Ploma, ha fatto degli professionali.
# [19:26.420 --> 19:30.420]  E che non permette l'accesso all'università?
# [19:30.420 --> 19:36.420]  Allora, questi qua sono, parente non convivvente, con lei, i genitori, porti pazienza,
# [19:37.420 --> 19:48.420]  abbiamo tutta questa scheda da compilare, parente, familiare, diverso del partner, con
# [19:48.420 --> 19:57.420]  vivente con lei, sono i figli, è il partner, con vivente con lei, e invece...
# [19:57.420 --> 19:59.420]  Marsilvia è una amica.
# [19:59.420 --> 20:04.420]  Lei sta aiutando queste persone in questo momento qua, il genitorio assolutamente,
# [20:04.420 --> 20:07.420]  i figli mi diceva di sì.
# [20:07.420 --> 20:13.420]  Il marito le sta aiutando in questo periodo su un marito o è...
# [20:13.420 --> 20:19.420]  È una piore che ha aiuto un'ilaterale, è un supporto bilaterale in Trambi.
# [20:19.420 --> 20:24.420]  E la sua amica Silvia, la sta aiutando, sta fornendo supporto anche in questo periodo
# [20:24.420 --> 20:26.420]  nella vita quotidiana.
# [20:27.420 --> 20:31.420]  Adesso, in questo periodo occuto in cui mi aveva messato il recuperata, no?
# [20:31.420 --> 20:39.420]  Però, come si dice, normalmente ci supporta la supporto spesso, ci sono un po' di contesti
# [20:39.420 --> 20:40.420]  particolari.
# [20:40.420 --> 20:45.420]  Indine, nel gli ultimi 12 mesi, diciamo, che lei sta dando supporto a queste persone
# [20:45.420 --> 20:46.420]  qui.
# [20:46.420 --> 20:50.420]  In gli ultimi 12 mesi le state il carghiver dei suoi genitori.
# [20:51.420 --> 20:57.420]  Ad il carghiver, ok, mentre delle altre persone, no, ma questo lo compilo io dopo,
# [20:57.420 --> 21:06.420]  anche per non portarle via del tempo, perché insomma, vola le carghiver di questa persona
# [21:06.420 --> 21:15.420]  anche in questo periodo qua, si diciamo le altre notte, le tipi di problemi che aveva,
# [21:16.420 --> 21:20.420]  che hanno i suoi genitori insomma, sono dovute l'invecchiamento, problemi dovute
# [21:20.420 --> 21:22.420]  apatologie croniche, dovute addisabilità.
# [21:22.420 --> 21:27.420]  Papa, invecchiamento, perché appunto gli hanno riscontrato l'alzheimer.
# [21:27.420 --> 21:28.420]  E la mamma?
# [21:28.420 --> 21:31.420]  E anche due più risposte.
# [21:31.420 --> 21:38.420]  La mamma invece, invecchiamento, in questa patologia, speriamo momentani,
# [21:39.420 --> 21:41.420]  quindi comunque le carghiver invecchiamento.
# [21:41.420 --> 21:45.420]  Ok, lasciamo l'ora invecchiamento, lasciamo.
# [21:45.420 --> 21:51.420]  Adesso, invece, passerei alla sezione degli aiutti che lei riceve, e quindi le chiederei
# [21:51.420 --> 21:58.420]  sempre rispetto alla scermata di prima che l'ha fatto vedere se indica il nome delle persone,
# [21:58.420 --> 22:03.420]  diverse da quelli di cui abbiamo parlato, alle quali lei ha dato supporto, le quali
# [22:03.420 --> 22:08.420]  le aiutato in questi ultimi 12 mesi, anche per un brevissimo periodo, ok?
# [22:08.420 --> 22:11.420]  No, no, in cui sono queste persone qua.
# [22:11.420 --> 22:12.420]  Ok.
# [22:12.420 --> 22:19.420]  E lei ha ricevuto supporto da altre persone diverse da quelli che abbiamo, ok?
# [22:19.420 --> 22:22.420]  Mi potrebbe in i cari nomi di Christian?
# [22:22.420 --> 22:26.420]  Allora, possiamo...
# [22:27.420 --> 22:31.420]  Beh, sicuramente l'alzheimer caffè mi ha dato la mano, quindi...
# [22:31.420 --> 22:33.420]  E' una persona che mi può indicare il nome di Christian?
# [22:33.420 --> 22:35.420]  L'ora, la corgola, l'ora.
# [22:35.420 --> 22:36.420]  L'ora, ok?
# [22:36.420 --> 22:38.420]  Questa cosa?
# [22:42.420 --> 22:47.420]  Sto pensando se gli assistenti sociali in Barbara Minervino?
# [22:47.420 --> 22:49.420]  Barbara?
# [22:49.420 --> 22:51.420]  Vasta.
# [22:51.420 --> 22:52.420]  Solo queste due.
# [22:52.420 --> 22:55.420]  Che tipo di supporto le ha dato?
# [22:56.420 --> 22:58.420]  Ritodenaro.
# [22:58.420 --> 23:03.420]  No, no, no, no, no, solo organizzativo, anche di come gestire appunto la malattia del
# [23:03.420 --> 23:07.420]  papà, come gestire i problemi della mamma e via.
# [23:07.420 --> 23:10.420]  Quindi direi un aiuto di tipo informativo?
# [23:10.420 --> 23:13.420]  Si, si.
# [23:13.420 --> 23:18.420]  Metto gestione qui.
# [23:18.420 --> 23:24.420]  No, le hanno fornito altri contatti di persone che magari le ha posti.
# [23:24.420 --> 23:26.420]  Si, si, si, anche.
# [23:26.420 --> 23:30.420]  Me hanno anche solo, si, me hanno fornito anche i contatti per poter contattare le persone
# [23:30.420 --> 23:34.420]  per avere informazioni operative, piuttosto che anche di supporto.
# [23:34.420 --> 23:36.420]  Si, si, è soltamente.
# [23:36.420 --> 23:44.420]  Le hanno fornito anche un supporto morale psicologico.
# [23:44.420 --> 23:46.420]  Si, assolutamente, si.
# [23:46.420 --> 23:48.420]  Entrambe queste persone.
# [23:48.420 --> 23:50.420]  Si, entrambe, entrambe.
# [23:50.420 --> 23:56.420]  E le hanno passato anche dei contatti magari non so.
# [23:56.420 --> 24:01.420]  L'hai contattato qualche medico, qualche professionista per conto di queste persone.
# [24:01.420 --> 24:04.420]  Oppure era più un aiuto.
# [24:04.420 --> 24:07.420]  No, in questo ambito no, no.
# [24:07.420 --> 24:08.420]  Ok, no.
# [24:08.420 --> 24:09.420]  Perfetto.
# [24:09.420 --> 24:13.420]  Ok, allora adesso le chiederai indicativamente anche delle informazioni,
# [24:13.420 --> 24:16.420]  socio-demografica su queste persone.
# [24:16.420 --> 24:19.420]  Stai leità di queste persone, non so se.
# [24:19.420 --> 24:21.420]  Non è l'altro molto indicativo.
# [24:21.420 --> 24:23.420]  Posso dire le stupereore ai 40 anni.
# [24:23.420 --> 24:31.420]  Una Laura inturora cinquantina e 3.40, 5.50 e Barbara 3.40 e 45.
# [24:31.420 --> 24:33.420]  Questo posso guidarle.
# [24:33.420 --> 24:34.420]  Non solo la loroità.
# [24:34.420 --> 24:36.420]  Mettiamo a 43, allora.
# [24:36.420 --> 24:39.420]  Il studio ha un'idea del titolo di studio di questi settori.
# [24:39.420 --> 24:41.420]  Tanto che siano tutte due laureate,
# [24:41.420 --> 24:44.420]  perché è un assistente sociale e l'altro psicologo,
# [24:44.420 --> 24:47.420]  quindi sicuramente le laureate.
# [24:47.420 --> 24:52.420]  Le relazioni che hanno sono altro,
# [24:52.420 --> 24:59.420]  quindi possiamo dire esperti nel settore.
# [24:59.420 --> 25:01.420]  Mi variabbe da dire.
# [25:01.420 --> 25:02.420]  Si, si.
# [25:02.420 --> 25:08.420]  Ok, annulla.
# [25:08.420 --> 25:11.420]  Perché non devo prendere l'ultima riga?
# [25:11.420 --> 25:12.420]  Perdone.
# [25:13.420 --> 25:15.420]  Ok.
# [25:15.420 --> 25:18.420]  Non me lo dava.
# [25:18.420 --> 25:20.420]  Meno segno io dopo insomma.
# [25:20.420 --> 25:21.420]  Ok.
# [25:21.420 --> 25:24.420]  Ome la sta aiutando anche in questo periodo oppure no.
# [25:24.420 --> 25:27.420]  Sì, sì, sì, sì, soltamente.
# [25:27.420 --> 25:30.420]  Ok, sì.
# [25:30.420 --> 25:32.420]  Sì.
# [25:32.420 --> 25:33.420]  Perfetto.
# [25:33.420 --> 25:36.420]  Allora, adesso le chiedereai un aspetto un po' particolare.
# [25:36.420 --> 25:38.420]  Questo è persone qui.
# [25:38.420 --> 25:41.420]  La stanno si aiutano tra di loro.
# [25:41.420 --> 25:44.420]  Desso non so se vede questa scheda qui,
# [25:44.420 --> 25:45.420]  però non è importante.
# [25:45.420 --> 25:46.420]  Io le dirò i nomi.
# [25:46.420 --> 25:49.420]  Quindi negli ultimi 12 mesi sono esistiti
# [25:49.420 --> 25:52.420]  dei legami di supporto o aiuto.
# [25:52.420 --> 25:55.420]  E quindi in caso di bisogno del corso della vita quotidiana,
# [25:55.420 --> 25:57.420]  tra le persone che ha menzionato e verso di lei,
# [25:57.420 --> 25:59.420]  da parte di quelle che l'ha aiutato.
# [25:59.420 --> 26:04.420]  Sasse queste si sono aiutate e si conoscono a vicenda.
# [26:05.420 --> 26:07.420]  Non ti conoscono, no?
# [26:07.420 --> 26:09.420]  Non c'è una relazione, il punto di contatto sono io,
# [26:09.420 --> 26:11.420]  ma sono due modi separati.
# [26:11.420 --> 26:13.420]  Ok.
# [26:13.420 --> 26:15.420]  Però diciamo che
# [26:15.420 --> 26:18.420]  tra
# [26:18.420 --> 26:22.420]  il suo apa
# [26:22.420 --> 26:25.420]  non l'ha fornito supporto,
# [26:25.420 --> 26:27.420]  perché lei che fornice supporto il suo apa.
# [26:27.420 --> 26:30.420]  E anche sua mamma non l'ha fornito supporto.
# [26:30.420 --> 26:31.420]  Ok.
# [26:31.420 --> 26:32.420]  Ok.
# [26:32.420 --> 26:33.420]  Perché il suo apa?
# [26:33.420 --> 26:37.420]  Giovanni Paolo forniscono supporto a lei i suoi figli.
# [26:37.420 --> 26:38.420]  Si?
# [26:38.420 --> 26:41.420]  Si, quindi questo si e anche Martina credo,
# [26:41.420 --> 26:43.420]  come Roberto,
# [26:43.420 --> 26:48.420]  le fornisce e anche Silvia e il supporto.
# [26:48.420 --> 26:51.420]  Ok.
# [26:51.420 --> 26:54.420]  Alfonso,
# [26:54.420 --> 26:56.420]  no, prisco.
# [26:56.420 --> 27:02.420]  Non so perché non mi ha preso le
# [27:02.420 --> 27:04.420]  in automatico i nomi.
# [27:04.420 --> 27:06.420]  E tra
# [27:06.420 --> 27:10.420]  alfonso, alfonzina non credo che ci sia su pao aiuto.
# [27:10.420 --> 27:11.420]  Per qui?
# [27:11.420 --> 27:12.420]  Si.
# [27:12.420 --> 27:14.420]  Ma mamma supporta tanto,
# [27:14.420 --> 27:19.420]  mi papà e mi papà in quei momenti di supporta anche mi amo.
# [27:19.420 --> 27:20.420]  Riesce allora.
# [27:20.420 --> 27:21.420]  Riesce anche su.
# [27:21.420 --> 27:22.420]  Motivamente, si.
# [27:22.420 --> 27:23.420]  Si.
# [27:23.420 --> 27:27.420]  E i nonni aiutano anche i nipoti diciamo.
# [27:27.420 --> 27:28.420]  Si, si, si.
# [27:28.420 --> 27:33.420]  Perché più in verso hanno aiutato i nipoti adesso i nipoti aiutano i nipoti.
# [27:33.420 --> 27:34.420]  Sono i nipoti.
# [27:34.420 --> 27:35.420]  Allora, si.
# [27:35.420 --> 27:36.420]  Quindi diciamo che i nonni non danno,
# [27:36.420 --> 27:39.420]  non riescono a dare un supporto.
# [27:39.420 --> 27:42.420]  I più ultimi 12 mesi sono i nipoti che aiutano i nipoti.
# [27:42.420 --> 27:43.420]  Si, si.
# [27:43.420 --> 27:51.420]  E neanche alle ai tecnici diciamo del caffè in un assistente sociale.
# [27:51.420 --> 27:52.420]  È fatto.
# [27:52.420 --> 27:55.420]  Alfonzina mi ha detto che aiuta su pao.
# [27:55.420 --> 27:58.420]  Con i poti diciamo, no, sono i nipoti che danno.
# [27:58.420 --> 28:01.420]  Ops, che danno sostegno.
# [28:01.420 --> 28:08.420]  No, anche qui.
# [28:08.420 --> 28:09.420]  No.
# [28:09.420 --> 28:11.420]  Allora, i nipoti diciamo.
# [28:11.420 --> 28:16.420]  Allora, questo caso Giovanni Paola aiuta a i nonni.
# [28:16.420 --> 28:17.420]  Si.
# [28:17.420 --> 28:21.420]  Giovanni Paola da un supporto anche Martina.
# [28:22.420 --> 28:24.420]  No.
# [28:24.420 --> 28:27.420]  No, non sono ancora abbastanza.
# [28:27.420 --> 28:30.420]  Sono una fase delle facciamo da soli.
# [28:30.420 --> 28:34.420]  E ad Alberto da un supporto.
# [28:34.420 --> 28:37.420]  Alberto, non supporto i ragazzi, ragazzi.
# [28:37.420 --> 28:40.420]  Beh, ai a loro modo aiutano anche Alberto.
# [28:40.420 --> 28:44.420]  Quindi c'è un supporto reciproco.
# [28:44.420 --> 28:46.420]  Con la sua mica silvia però non credo.
# [28:46.420 --> 28:48.420]  No, no, esatto.
# [28:48.420 --> 28:50.420]  È un po' il colante, ok?
# [28:50.420 --> 28:51.420]  Esatto.
# [28:51.420 --> 28:54.420]  Martina aiuta in onni.
# [28:54.420 --> 28:55.420]  Si.
# [28:55.420 --> 28:57.420]  Giovanni anche il fratello.
# [28:57.420 --> 28:59.420]  Martina oppure non.
# [28:59.420 --> 29:00.420]  E come il fratello?
# [29:00.420 --> 29:06.420]  Puoi fare copi in colla la solita di Giovanni Paolo e coperla su Martina.
# [29:06.420 --> 29:08.420]  Piava però forse era in decisa prima.
# [29:08.420 --> 29:09.420]  Non molto.
# [29:09.420 --> 29:10.420]  Non si convinto.
# [29:10.420 --> 29:11.420]  Mi sembrava.
# [29:11.420 --> 29:14.420]  No, ma perché sono ancora nella fase.
# [29:14.420 --> 29:17.420]  Si aiutano, ma poi non si aiutano.
# [29:17.420 --> 29:20.420]  Non ci sono le buon intenzione, ma non ci sono poi fatti.
# [29:20.420 --> 29:21.420]  Ok.
# [29:21.420 --> 29:22.420]  Ok.
# [29:22.420 --> 29:24.420]  Metti a mano qua.
# [29:24.420 --> 29:27.420]  Invece, Alberto aiuta ai suoi genitori o.
# [29:27.420 --> 29:28.420]  I suoi genitori.
# [32:57.420 --> 32:58.420]  D'accordo.
# [32:58.420 --> 33:00.420]  D'accordo.
# [33:00.420 --> 33:01.420]  D'accordo.
# [33:01.420 --> 33:04.420]  D'accordo.
# [33:04.420 --> 33:05.420]  D'accordo.
# [33:05.420 --> 33:07.420]  D'accordo.
# [33:07.420 --> 33:10.420]  D'accordo.
# [33:10.420 --> 33:11.420]  D'accordo.
# [33:11.420 --> 33:12.420]  D'accordo.
# [33:12.420 --> 33:13.420]  D'accordo.
# [33:13.420 --> 33:14.420]  D'accordo.
# [33:14.420 --> 33:17.420]  D'accordo.
# [33:17.420 --> 33:18.420]  D'accordo.
# [33:18.420 --> 33:23.420]  D'accordo.
# [33:23.420 --> 33:25.420]  D'accordo.
# [33:25.420 --> 33:26.420]  D'accordo.
# [33:26.420 --> 33:27.420]  D'accordo.
# [33:27.420 --> 33:30.420]  Siete? Sono una persona che...
# [33:30.420 --> 33:34.620]  Ok. E' utilizzando la scala di valore quanto si fila
# [33:34.620 --> 33:37.620]  complessivamente del sistema politico-democratico.
# [33:40.120 --> 33:44.920]  Politico-democratico un po' meno sono sul sei,
# [33:44.920 --> 33:50.920]  sono proprio perché al cidevi comunque essere un rientamento a questo,
# [33:50.920 --> 33:51.920]  quindi sul sei.
# [33:52.420 --> 33:55.920]  E sul sistema economico complessivamente del sistema economico
# [33:56.920 --> 34:00.920]  Il bufינolet Break Generali ha fatto che esté fondateli
# [34:00.920 --> 34:04.920]  e che mi vedono in questo periodo storico nel mondo, ecclo?
# [34:07.420 --> 34:08.980]  Spara fur הב�oowello.
# [34:10.020 --> 34:15.220]  Ok. Allora, perfetto. Passarai quindi all'ultima sezione che sono le demande socialdemogranse.
# [34:16.220 --> 34:19.720]  credere chi è il vendito su tratto di studio.
# [34:20.120 --> 34:24.880]  Di próma all'università per l' Experimento
# [34:24.880 --> 34:37.840]  impresa quindi lei è lavoratore in prontio e soci dell'azienda, si però è non è
# [34:37.840 --> 34:47.080]  dipendente e quindi libro professionista, no no no sono prenditrice, prenditrice esatto,
# [34:47.080 --> 34:56.760]  giana artigiana con dipendenti o in prenditrice, prenditore quindi in prenditrice, ok lasciamo
# [34:56.760 --> 35:02.920]  questo e da quante persone composto suonucro mi sembra quattro suonucro familiare che mi diceva
# [35:02.920 --> 35:20.240]  sì, ok e vive quindi con coniuge e avete figli, le agitalienze italiana, l'ultima domanda riguarda
# [35:20.240 --> 35:27.000]  il reddito mensile, qua siamo sulle fasce fino a 1.000 euro, da 1.100 a 2.000 euro, da 2.100 a 4.000
# [35:27.120 --> 35:35.640]  euro, oltre i 4.000 euro, da 2.100 a 4.000 euro, ok perfetto, allora questa qui come le diceva appunto
# [35:35.640 --> 35:43.960]  e la ringrazie per questo tempo riguarda la struttura delle sue areti ed era una parte insomma
# [35:43.960 --> 35:48.840]  dell'intervista perché l'intervista è un postandardizzata come ha visto abbiamo domande standardizzate
# [35:48.840 --> 35:55.320]  allora adesso questa posto interrompere è la condivisione, il secondo step della ritorno sui
# [35:55.320 --> 36:03.920]  il mio schermo, del dell'intervista sarebbe un'intervista discorsiva aperta, ci raccontava però sarebbe
# [36:03.920 --> 36:10.120]  un'intervista in modalità di adica, ok quindi da fare anche con un'altra persona e la persona
# [36:10.120 --> 36:17.280]  da identificare sarebbe la persona creda più supporto in questo momento, in questo momento
# [36:17.280 --> 36:22.280]  diciamo che la persona è più supporto sono e mi è marito che in questo momento però non c'è
# [36:22.280 --> 36:29.480]  non non un questo momento fare l'intervista, in generale si stino dico, qui dicamente adesso mi
# [36:29.480 --> 36:34.480]  avruttimmente che mi avrete di questa cosa si potevo coinvolgere una persona ma mi
# [36:34.480 --> 36:38.680]  avevo adesso come l'aderto mi avevo l'intervista in mente, mi sono risolto, però
# [36:38.680 --> 36:44.800]  io lo credo poi tutti le vicissitudes della settimana è comprensibile insomma, qui anche se vuole
# [36:44.800 --> 36:49.440]  aggiungere qualcosa, hanno più sperienza di messo l'intervista di adica, però l'intervista di
# [36:49.440 --> 36:55.480]  adica va fatta tra l'intervistatore e due persone, quindi vogliamo sapere, cioè sapere vogliamo
# [36:55.480 --> 37:01.560]  così che il caregiver ci racconti la sua sperienza con anche la persona che supporta il caregiver e
# [37:01.560 --> 37:08.360]  quindi servirebbe la persona creda più supporto identificare questa persona e poi una volta identificata
# [37:08.360 --> 37:15.520]  questa persona ci fissiamo un appuntamento e sempre in zoom così registriamo l'intervista e poi
# [37:15.520 --> 37:22.440]  noi raccogliate, domande, ok? Per cui c'è utile conoscere, quindi anche nome con nome o
# [37:22.440 --> 37:27.280]  riferimento di mail dell'altra persona, perché proprio a fine della conclusione, della ricerca,
# [37:27.280 --> 37:33.600]  inviaremo riconoscimento a chi ha partecipato insomma anche per ingraziarli dal tempo che
# [37:33.600 --> 37:37.240]  hanno messo a disposizione queste persone qui, ok?
# [37:37.240 --> 37:37.360]  Alberto, il mio marito, che adesso indirizzo me in questo momento mi sfugge, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no, no
# [38:07.240 --> 38:09.240]  no, no, no, no, no, no, no
# [38:37.240 --> 38:51.240]  ma se odio se è scappata, se è scollegata, se è sconnessa vediamo se si riconnette, c'è stato
# [38:51.240 --> 38:58.040]  qualche ingipo nel file excel, non so perché anna e dopo roco di controllo, ma mi è che questa
# [38:58.040 --> 39:04.840]  mattina ho provato a metterci mano, se vuole aggiungere qualcosa sull'intervista, ecco la qui
# [39:04.840 --> 39:09.440]  che la mettiamo, se voglio aggiungere qualcosa sull'intervista di adic, lei anna che a più esperienze di
# [39:09.440 --> 39:22.480]  me così raccontiamo un attimo a Fiorella, è assaltata la linea, ci scusi, sì sì sì sì no no siamo
# [39:22.480 --> 39:27.520]  ancora qui, non so se anna vuole raccontare qualcosa di più sull'intervista di adic, per quelle
# [39:27.520 --> 39:32.760]  servirà magari adesso abbiamo impiegato un po' misorita a 3 quarti d'ora per questo, per l'intervista
# [39:32.760 --> 39:37.120]  servirà un po' più di tempo insomma perché quando si in cominci a parlare si raccontano le
# [39:37.120 --> 39:43.720]  esperienze e questo veramente è in fondamentale per noi, quindi a mettere già in preventivo più di
# [39:43.720 --> 39:52.920]  un oretta, ok, un ore mezza ok, ma bene, ma bene, ma bene, certo, poi di organizzare in loro
# [39:52.920 --> 39:58.160]  arro in cui possiamo dedicare quali fai il devore, sì anche più tardi se per voi è più comodo,
# [39:58.160 --> 40:05.960]  ok, tanto io come il cercatore ha la disponibilità insomma sono flessibile non ho problemi, ok,
# [40:05.960 --> 40:15.120]  non so se anna vuole aggiungere qualcosa oppure, cioè scegliere un'intervista di adic, invece
# [40:15.120 --> 40:31.600]  un'intervista singola ci aiuta, ci aiuta a capire le mellole relazioni, a capire un due punti di vista
# [40:31.600 --> 40:40.480]  e le relazioni, quindi questo è importante, cosa che non sarebbe possibile con un'intervista,
# [40:41.040 --> 40:48.160]  e non sarebbe possibile neanche con due intervista singolesi, ci fa vedere un'intervista di adic,
# [40:48.160 --> 40:57.440]  delle cose che non riusciremo a vedere con due intervista singoles o solo con una intervista,
# [40:57.440 --> 41:03.280]  quindi vediamo, condivido capisco il punto di vista, ecco quindi l'altra persona però dovrebbe
# [41:03.280 --> 41:11.280]  essere fisicamente proprio presente nella stanza, dovrebbe per creare quella dinamica di supporto
# [41:11.280 --> 41:17.800]  di relazioni tra, ho capito chiaro, mi è molto chiaro, io dirai di sentirci in settimana per i
# [41:17.800 --> 41:28.000]  meyla e così confermiamo magari per sabato prossimo, volentieri, noi la lasciamo, io rimango un
# [41:28.000 --> 41:34.320]  attimo con Anna, se può, grazie ancora, pariamo che tutto proceda per il meglio per i suoi genitori,
# [41:34.320 --> 41:46.000]  ecco e grazie di questa disponibilità. Grazie a voi, buon lavoro, a grazie, grazie, grazie, grazie, grazie.
# [41:46.000 --> 41:54.000]  Grazie. Grazie allora, devo capire nel file cosa è successo, perché in questo file come è
# [41:54.000 --> 42:02.000]  visto questa mattina le mani un attimo per fare le prove ancora, quindi si è sfasato, ha capito
# [42:02.000 --> 42:12.000]  per un po' il meccanismo. Sì, sì, sì, sì, sì, no, era, diciamo che così è chiarissimo, raccontata,
# [42:12.000 --> 42:22.000]  raccontata, invece che vista di retamente sembra molto più, molto complicata. La professoresse di
# [42:22.000 --> 42:30.000]  dovevo mostrarla gli intervistati, però visto che c'era anche lei questa volta la mostrata, perché, però, forse,
# [42:30.000 --> 42:37.000]  sì, secondo me uno come si organizza meglio, va meglio la persona come si organizza, perché poi vede
# [42:37.000 --> 42:44.000]  non sto pensando, sto pensando in cosa può, in cosa può influire negativamente che è
# [42:44.000 --> 42:54.000]  l'intervistato, se si fa vedere un foglio per volta in un tutto insieme, sto pensando cosa può, cosa può.
# [42:56.000 --> 43:04.000]  Non saprei, perché come vede qua l'intervistata partiva andava, parlava, non seguiva un po' la standardazione.
# [43:04.000 --> 43:13.000]  Usano il cellulare e quindi magari non vedono neanche bene il foglio, quindi sì, non è che abbia
# [43:13.000 --> 43:21.000]  influito anche secondo me in questo momento qui, perché non seguono, loro raccontano gli aiuti che danno,
# [43:21.000 --> 43:28.000]  difficili anche per loro in quadrarli, questa intervista qui sarebbe più riascarmo, si leggono a scarmo
# [43:28.000 --> 43:33.000]  le domande e ognuno le compile, quindi così per loro è più difficile, è più.
# [43:33.000 --> 43:44.000]  No, ecco, ha suggerimenti da dare anche sul mio modo di fare interviste o somministrare questa scheda
# [43:44.000 --> 43:48.000]  Anna adesso, così ne ha profito per imparare e perfezionare.
# [43:48.000 --> 43:51.000]  Per carità.
# [43:51.000 --> 43:57.000]  No, no, no, direi che ha funzionato tutto.
# [43:58.000 --> 44:04.000]  Sì, e poi bisogna stare un po' nei tempi, perché secondo me anche loro, almeno su cui è stati dedicare più tempo
# [44:04.000 --> 44:06.000]  alla diadica.
# [44:06.000 --> 44:07.000]  Sì.
# [44:07.000 --> 44:10.000]  Sì, vi bisogna proprio lasciare parlare.
# [44:10.000 --> 44:11.000]  Sì, sì.
# [44:11.000 --> 44:12.000]  Quindi intanto.
# [44:12.000 --> 44:21.000]  Vi dispiaceva interrompre l'intervistata perché anche l'inizio era partita raccontando gli aiuti che dava e che riceveva,
# [44:21.000 --> 44:27.000]  ma bisognerebbe stare nella griglia e quando uno parla tempo vola e non vorrei portarvi a molto tempo,
# [44:27.000 --> 44:30.000]  che poi si sta anche in linea di...
# [44:30.000 --> 44:32.000]  Ah, sì.
# [44:32.000 --> 44:35.000]  E quindi va beh.
# [44:35.000 --> 44:39.000]  E' questo un po' il meccanismo, va bene?
# [44:39.000 --> 44:42.000]  Sì, sì, va bene.
# [44:42.000 --> 44:47.000]  Allora, io se posso prendere contatto con qualcuno vero di...
# [44:47.000 --> 44:48.000]  Vi lo giro.
# [44:48.000 --> 44:49.000]  Già oggi pomerì.
# [44:49.000 --> 44:50.000]  Sì.
# [44:50.000 --> 44:51.000]  Atto di qualsiasi.
# [44:51.000 --> 44:52.000]  Sì, sì, sì.
# [44:52.000 --> 44:55.000]  Così mi ci ho chiedere se...
# [44:55.000 --> 44:57.000]  Se e quando?
# [44:57.000 --> 45:02.000]  Perché guardi, c'era stata, già una persona che mi aveva scritto di essere...
# [45:02.000 --> 45:05.000]  Vabbè che l'avevo contattato io la settimana prossima.
# [45:05.000 --> 45:10.000]  Vediamo come si chiama questa persona qui.
# [45:10.000 --> 45:17.000]  E' un attimo solo ricerche, non divenetica, quassa croquore.
# [45:17.000 --> 45:25.000]  E' restata ritta.
# [45:25.000 --> 45:28.000]  Questa spessione...
# [45:28.000 --> 45:30.000]  Qua mi dice, mi può contattare?
# [45:30.000 --> 45:34.000]  Tutti i giorni, face oraria, dalle quattordice, le dice a sette.
# [45:34.000 --> 45:41.000]  Potrei risponterle mettendo in Cicilei che la contatera lei e che se ne occuperà lei...
# [45:41.000 --> 45:45.000]  Sì, sì, direi di sì dire che va benissimo.
# [45:45.000 --> 45:47.000]  Ok, perfetto, dai.
# [45:47.000 --> 45:52.000]  Allora, le mando subito questo contatto.
# [45:52.000 --> 45:55.000]  E poi noi c'era giorni a me.
# [45:55.000 --> 45:56.000]  Sì.
# [45:56.000 --> 45:57.000]  Sì.
# [45:57.000 --> 45:58.000]  Sì.
# [45:58.000 --> 46:01.000]  Sì, no bene.
# [46:01.000 --> 46:05.000]  Ok, allora posso interpretare la registrazione?
# [46:05.000 --> 46:07.000]  Sì.
